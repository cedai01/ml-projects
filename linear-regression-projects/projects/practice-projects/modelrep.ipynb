# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
import os
print(os.path.exists("ml-projects/Datasets/Salary_dataset.csv"))
# Out:
# False

# %%
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
x_train = df["Salary"].values
y_train = df["YearsExperience"].values 

w = 0
b = 0

# %%
def compute_model_output(x, w, b):

    m = x_train.shape[0]
    f_wb = np.zeros(m)
    for i in range(m):
        f_wb[i] = w * x[i] + b
    
    return f_wb

# %%
all_fw_b = compute_model_output(x_train, w, b)
plt.scatter(x_train, y_train, marker="x", color="r", label="Actual values")
plt.plot(x_train, all_fw_b, color="b", label="our prediction")

plt.title("Years of Experience and Salary progression")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.legend()
plt.show()

# %%
w = 1000                          
b = 100    

cost_1200sqft = w * x_train + b 
print(cost_1200sqft)
# Out:
# 0      1300.0
# 1      1500.0
# 2      1700.0
# 3      2200.0
# 4      2400.0
# 5      3100.0
# 6      3200.0
# 7      3400.0
# 8      3400.0
# 9      3900.0
# 10     4100.0
# 11     4200.0
# 12     4200.0
# 13     4300.0
# 14     4700.0
# 15     5100.0
# 16     5300.0
# 17     5500.0
# 18     6100.0
# 19     6200.0
# 20     7000.0
# 21     7300.0
# 22     8100.0
# 23     8400.0
# 24     8900.0
# 25     9200.0
# 26     9700.0
# 27     9800.0
# 28    10500.0
# 29    10700.0
# Name: YearsExperience, dtype: float64
